# %% [markdown]
# # A Gentle Introduction to Reinforcement Learning

# %% [markdown]
# # Reinforcement Learning with Python

# %% [markdown]
# ## 1. Installing and Importing Dependencies

# %%
# !pip install 'stable-baselines3[extra]'
# !pip install wandb
# Out:
# Requirement already satisfied: stable-baselines3[extra] in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (1.6.2)
# Requirement already satisfied: gym==0.21 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: matplotlib in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (3.6.1)
# Requirement already satisfied: pandas in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.5.0)
# Requirement already satisfied: numpy in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.22.4)
# Requirement already satisfied: torch>=1.11 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (1.12.1)
# Requirement already satisfied: importlib-metadata~=4.13 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: cloudpickle in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: rich in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (12.6.0)
# Requirement already satisfied: psutil in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (5.9.2)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: pillow in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (9.2.0)
# Requirement already satisfied: tqdm in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (4.64.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (2.10.1)
# Requirement already satisfied: ale-py==0.7.4 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: opencv-python in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from stable-baselines3[extra]) (4.6.0.66)
# Requirement already satisfied: importlib-resources in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.10.0)
# Requirement already satisfied: requests in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.28.1)
# Requirement already satisfied: click in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: AutoROM.accept-rom-license in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.9.0)
# Requirement already satisfied: wheel>=0.26 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: absl-py>=0.4 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: grpcio>=1.24.3 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.49.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.35.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.19.6)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (49.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: typing-extensions in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[extra]) (4.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (4.37.4)
# Requirement already satisfied: cycler>=0.10 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from pandas->stable-baselines3[extra]) (2022.4)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from rich->stable-baselines3[extra]) (2.13.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from rich->stable-baselines3[extra]) (0.9.1)
# Requirement already satisfied: six in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from absl-py>=0.4->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: wandb in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (0.13.4)
# Requirement already satisfied: shortuuid>=0.5.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (1.0.9)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (8.0.4)
# Requirement already satisfied: pathtools in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (0.1.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (2.28.1)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (1.9.0)
# Requirement already satisfied: PyYAML in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (5.4.1)
# Requirement already satisfied: setproctitle in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (1.3.2)
# Requirement already satisfied: promise<3,>=2.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (2.3)
# Requirement already satisfied: GitPython>=1.0.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (3.1.28)
# Requirement already satisfied: psutil>=5.0.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (5.9.2)
# Requirement already satisfied: six>=1.13.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (1.16.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.0,<5,>=3.12.0 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (3.19.6)
# Requirement already satisfied: setuptools in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from wandb) (49.2.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from GitPython>=1.0.0->wandb) (4.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (1.26.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/mukilankrishnakumar/.pyenv/versions/3.8.6/envs/zenml/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (5.0.0)

# %%
import gym
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## 2. Load Environment

# %%
env = gym.make('CarRacing-v0')
env = DummyVecEnv([lambda:env])

# %% [markdown]
# ## 3. Train RL Model

# %%
log_path = os.path.join('Training','Logs')

model = PPO('MlpPolicy', env, verbose = 1)

model.learn(total_timesteps = 20000)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Track generation: 1108..1396 -> 288-tiles track
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1211..1518 -> 307-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 177  |
# |    iterations      | 1    |
# |    time_elapsed    | 11   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1136..1424 -> 288-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 2           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008181527 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.000172    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.623       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00752    |
# |    std                  | 0.983       |
# |    value_loss           | 1.06        |
# -----------------------------------------
# Track generation: 1244..1559 -> 315-tiles track
# Track generation: 1073..1351 -> 278-tiles track
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 123          |
# |    iterations           | 3            |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0051446874 |
# |    clip_fraction        | 0.0585       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.19        |
# |    explained_variance   | 0.0086       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.552        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00436     |
# |    std                  | 0.973        |
# |    value_loss           | 0.817        |
# ------------------------------------------
# Track generation: 1044..1309 -> 265-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 4            |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0073880143 |
# |    clip_fraction        | 0.0715       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | 0.0117       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.36         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00545     |
# |    std                  | 0.963        |
# |    value_loss           | 0.954        |
# ------------------------------------------
# Track generation: 1192..1495 -> 303-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 5            |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0074976934 |
# |    clip_fraction        | 0.0842       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | 0.0135       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.65         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00772     |
# |    std                  | 0.961        |
# |    value_loss           | 1.14         |
# ------------------------------------------
# Track generation: 1042..1310 -> 268-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1071..1345 -> 274-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1306..1646 -> 340-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 6           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009351079 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.0162      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.516       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00659    |
# |    std                  | 0.94        |
# |    value_loss           | 1.17        |
# -----------------------------------------
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1000..1254 -> 254-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 7           |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005433127 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.0249      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.484       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00525    |
# |    std                  | 0.934       |
# |    value_loss           | 1.03        |
# -----------------------------------------
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1208..1514 -> 306-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 8           |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005904574 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.0345      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.529       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0029     |
# |    std                  | 0.921       |
# |    value_loss           | 1.24        |
# -----------------------------------------
# Track generation: 1204..1509 -> 305-tiles track
# Track generation: 1068..1339 -> 271-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 9           |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008340594 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.0234      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.469       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00476    |
# |    std                  | 0.905       |
# |    value_loss           | 1.22        |
# -----------------------------------------
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 944..1190 -> 246-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 10          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005676096 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.0231      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.442       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00264    |
# |    std                  | 0.896       |
# |    value_loss           | 1.56        |
# -----------------------------------------

# %% [markdown]
# ## 4. Evaluate the RL Model

# %%
evaluate_policy(model,env,n_eval_episodes = 10, render = True)
# Out:
# /Users/mukilankrishnakumar/.pyenv/versions/zenml/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1039..1305 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1011..1268 -> 257-tiles track
# Track generation: 1088..1364 -> 276-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1084..1368 -> 284-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1023..1290 -> 267-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1090..1367 -> 277-tiles track
# Track generation: 1060..1328 -> 268-tiles track
# (-45.58824533745646, 12.061828955619957)

# %% [markdown]
# # Tracking your Reinforcement Learning models with Weights and Biases

# %% [markdown]
# ## 1. Importing Libraries

# %%
import gym
import os 
import wandb
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv,VecVideoRecorder
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from wandb.integration.sb3 import WandbCallback

# %% [markdown]
# ## 2. Initialising our Run

# %%
config = {
    "policy_type": "MlpPolicy",
    "total_timesteps": 250000,
    "env_name": "CarRacing-v0",
}
run = wandb.init(
    project="intro_to_rl",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    monitor_gym=True,  # auto-upload the videos of agents playing the game
    save_code=True,  
)
# Out:
# wandb: Currently logged in as: mukilan. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/wandb/run-20221029_083636-3cv0xc49</code>
# Syncing run <strong><a href="https://wandb.ai/mukilan/intro_to_rl/runs/3cv0xc49" target="_blank">devoted-glitter-1</a></strong> to <a href="https://wandb.ai/mukilan/intro_to_rl" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %% [markdown]
# ## 3. Load Environment

# %%
def make_env():
    env = gym.make(config["env_name"])
    env = Monitor(env)  # record stats such as returns
    return env

# %%
env = DummyVecEnv([make_env])
env = VecVideoRecorder(env, f"videos/{run.id}", record_video_trigger=lambda x: x % 2000 == 0, video_length=200)

# %% [markdown]
# ## 4. Train RL Model

# %%
model = PPO(config["policy_type"], env, verbose=1, tensorboard_log=f"runs/{run.id}")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(
    total_timesteps=config["total_timesteps"],
    callback=WandbCallback(
        gradient_save_freq=100,
        model_save_path=f"models/{run.id}",
        verbose=2,
    ),
)
# Out:
# Track generation: 1180..1479 -> 299-tiles track
# Logging to runs/3cv0xc49/PPO_1
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-0-to-step-200.mp4
# Track generation: 1005..1267 -> 262-tiles track
# Track generation: 1101..1380 -> 279-tiles track
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -53.3    |
# | time/              |          |
# |    fps             | 88       |
# |    iterations      | 1        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-2000-to-step-2200.mp4
# Track generation: 1107..1388 -> 281-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.8       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 2           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010040481 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | -0.00501    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.66        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0063     |
# |    std                  | 0.983       |
# |    value_loss           | 1.09        |
# -----------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-4000-to-step-4200.mp4
# Track generation: 1138..1426 -> 288-tiles track
# Track generation: 1121..1405 -> 284-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 3           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004299577 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.419       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00293    |
# |    std                  | 0.98        |
# |    value_loss           | 0.908       |
# -----------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-6000-to-step-6200.mp4
# Track generation: 1191..1501 -> 310-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.5       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 4           |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005535211 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.398       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00376    |
# |    std                  | 0.964       |
# |    value_loss           | 0.908       |
# -----------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-8000-to-step-8200.mp4
# Track generation: 1090..1371 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1350..1692 -> 342-tiles track
# Track generation: 1117..1405 -> 288-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-10000-to-step-10200.mp4
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -45.1        |
# | time/                   |              |
# |    fps                  | 87           |
# |    iterations           | 5            |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0056469226 |
# |    clip_fraction        | 0.0965       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.371        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00791     |
# |    std                  | 0.959        |
# |    value_loss           | 0.943        |
# ------------------------------------------
# Track generation: 1230..1542 -> 312-tiles track
# Track generation: 1192..1500 -> 308-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-12000-to-step-12200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.1       |
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 6           |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007287166 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.00289     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.528       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00717    |
# |    std                  | 0.94        |
# |    value_loss           | 1.08        |
# -----------------------------------------
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1008..1264 -> 256-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-14000-to-step-14200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43.8       |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 7           |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005129466 |
# |    clip_fraction        | 0.0644      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.69        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00489    |
# |    std                  | 0.927       |
# |    value_loss           | 1.06        |
# -----------------------------------------
# Track generation: 1093..1370 -> 277-tiles track
# Track generation: 1026..1294 -> 268-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-16000-to-step-16200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -41.4       |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 8           |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005391379 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.77        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00132    |
# |    std                  | 0.91        |
# |    value_loss           | 1.38        |
# -----------------------------------------
# Track generation: 1063..1340 -> 277-tiles track
# Track generation: 1090..1373 -> 283-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-18000-to-step-18200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43         |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 9           |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006330718 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.733       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00635    |
# |    std                  | 0.894       |
# |    value_loss           | 1.41        |
# -----------------------------------------
# Track generation: 1169..1465 -> 296-tiles track
# Track generation: 1034..1303 -> 269-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-20000-to-step-20200.mp4
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -42.9        |
# | time/                   |              |
# |    fps                  | 89           |
# |    iterations           | 10           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0041226116 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.91        |
# |    explained_variance   | 0.00304      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.674        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.00043      |
# |    std                  | 0.89         |
# |    value_loss           | 1.21         |
# ------------------------------------------
# Track generation: 1215..1523 -> 308-tiles track
# Track generation: 976..1224 -> 248-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-22000-to-step-22200.mp4
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -43.9        |
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 11           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0037406099 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.88        |
# |    explained_variance   | 0.00525      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.866        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00299     |
# |    std                  | 0.873        |
# |    value_loss           | 1.63         |
# ------------------------------------------
# Track generation: 1318..1652 -> 334-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-24000-to-step-24200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -40.6       |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 12          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006964963 |
# |    clip_fraction        | 0.0659      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.00375     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00415    |
# |    std                  | 0.865       |
# |    value_loss           | 2.84        |
# -----------------------------------------
# Track generation: 1123..1408 -> 285-tiles track
# Track generation: 1066..1342 -> 276-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-26000-to-step-26200.mp4
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -40          |
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 13           |
# |    time_elapsed         | 292          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0049438863 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.81        |
# |    explained_variance   | 0.00521      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.872        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00325     |
# |    std                  | 0.859        |
# |    value_loss           | 2.6          |
# ------------------------------------------
# Track generation: 1291..1609 -> 318-tiles track
# Track generation: 1264..1584 -> 320-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-28000-to-step-28200.mp4
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -39.6        |
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 14           |
# |    time_elapsed         | 314          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0037491599 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.77        |
# |    explained_variance   | 0.00632      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00222     |
# |    std                  | 0.846        |
# |    value_loss           | 3.94         |
# ------------------------------------------
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1093..1374 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1163..1458 -> 295-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-30000-to-step-30200.mp4
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -40.7        |
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 15           |
# |    time_elapsed         | 335          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0027231802 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.74        |
# |    explained_variance   | 0.0137       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.000329     |
# |    std                  | 0.842        |
# |    value_loss           | 2.15         |
# ------------------------------------------
# Track generation: 1087..1371 -> 284-tiles track
# Track generation: 1099..1378 -> 279-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-32000-to-step-32200.mp4
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -41.2        |
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 16           |
# |    time_elapsed         | 357          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0039744484 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.72        |
# |    explained_variance   | 0.0102       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.683        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000188    |
# |    std                  | 0.836        |
# |    value_loss           | 2.09         |
# ------------------------------------------
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1156..1449 -> 293-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-34000-to-step-34200.mp4
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -41.1        |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 17           |
# |    time_elapsed         | 378          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0070984457 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.68        |
# |    explained_variance   | 0.0166       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.926        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00772     |
# |    std                  | 0.819        |
# |    value_loss           | 2.39         |
# ------------------------------------------
# Track generation: 1149..1440 -> 291-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-36000-to-step-36200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -42.6       |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 18          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004294893 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.0266      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.98        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 4.04e-06    |
# |    std                  | 0.807       |
# |    value_loss           | 2.52        |
# -----------------------------------------
# Track generation: 1133..1420 -> 287-tiles track
# Track generation: 1297..1625 -> 328-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-38000-to-step-38200.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43.3       |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 19          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.003843047 |
# |    clip_fraction        | 0.0291      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.0127      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00126     |
# |    std                  | 0.799       |
# |    value_loss           | 2.97        |
# -----------------------------------------
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1119..1403 -> 284-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-40000-to-step-40200.mp4
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -42.9        |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 20           |
# |    time_elapsed         | 444          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0053372593 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.58        |
# |    explained_variance   | 0.0326       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.564        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00119     |
# |    std                  | 0.801        |
# |    value_loss           | 1.05         |
# ------------------------------------------
# Track generation: 1129..1423 -> 294-tiles track
# Track generation: 928..1170 -> 242-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-42000-to-step-42200.mp4
# Track generation: 1243..1558 -> 315-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.7       |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 21          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004659063 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.57       |
# |    explained_variance   | 0.00804     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.64        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.000796   |
# |    std                  | 0.793       |
# |    value_loss           | 4.05        |
# -----------------------------------------
# Track generation: 1183..1483 -> 300-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-44000-to-step-44200.mp4
# Track generation: 1134..1422 -> 288-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -44.6      |
# | time/                   |            |
# |    fps                  | 91         |
# |    iterations           | 22         |
# |    time_elapsed         | 490        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00552041 |
# |    clip_fraction        | 0.039      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.54      |
# |    explained_variance   | 0.0521     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.02       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.000845  |
# |    std                  | 0.788      |
# |    value_loss           | 1.35       |
# ----------------------------------------
# Track generation: 1191..1493 -> 302-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-46000-to-step-46200.mp4
# Track generation: 1263..1583 -> 320-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -43.1        |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 23           |
# |    time_elapsed         | 511          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0059947018 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.51        |
# |    explained_variance   | 0.0108       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.89         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00322     |
# |    std                  | 0.773        |
# |    value_loss           | 3.41         |
# ------------------------------------------
# Track generation: 1117..1400 -> 283-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-48000-to-step-48200.mp4
# Track generation: 1159..1453 -> 294-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -43.1        |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 24           |
# |    time_elapsed         | 533          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0059367106 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.47        |
# |    explained_variance   | 0.00391      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.77         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0026      |
# |    std                  | 0.768        |
# |    value_loss           | 7.67         |
# ------------------------------------------
# Track generation: 1135..1424 -> 289-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-50000-to-step-50200.mp4
# Track generation: 1268..1589 -> 321-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43.3       |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 25          |
# |    time_elapsed         | 554         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.002136872 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.44       |
# |    explained_variance   | 0.0142      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.981       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.000221    |
# |    std                  | 0.758       |
# |    value_loss           | 3.06        |
# -----------------------------------------
# Track generation: 1037..1300 -> 263-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-52000-to-step-52200.mp4
# Track generation: 1051..1324 -> 273-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -43.9        |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 26           |
# |    time_elapsed         | 575          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0041839536 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.42        |
# |    explained_variance   | 0.0769       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.606        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000607    |
# |    std                  | 0.758        |
# |    value_loss           | 2.31         |
# ------------------------------------------
# Track generation: 1340..1679 -> 339-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-54000-to-step-54200.mp4
# Track generation: 1384..1734 -> 350-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43.3       |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 27          |
# |    time_elapsed         | 597         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004185995 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.0713      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.756       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0017     |
# |    std                  | 0.76        |
# |    value_loss           | 2.76        |
# -----------------------------------------
# Track generation: 984..1234 -> 250-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-56000-to-step-56200.mp4
# Track generation: 1170..1474 -> 304-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43.1       |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 28          |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005054135 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.0344      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00136    |
# |    std                  | 0.752       |
# |    value_loss           | 4.52        |
# -----------------------------------------
# Track generation: 1157..1461 -> 304-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-58000-to-step-58200.mp4
# Track generation: 1159..1453 -> 294-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -41.7        |
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 29           |
# |    time_elapsed         | 643          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0070489035 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.37        |
# |    explained_variance   | 0.0438       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.83         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00203     |
# |    std                  | 0.741        |
# |    value_loss           | 4.38         |
# ------------------------------------------
# Track generation: 1172..1469 -> 297-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-60000-to-step-60200.mp4
# Track generation: 1211..1517 -> 306-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -41.6       |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 30          |
# |    time_elapsed         | 666         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004900839 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.33       |
# |    explained_variance   | 0.0213      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.1         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00191    |
# |    std                  | 0.73        |
# |    value_loss           | 5.98        |
# -----------------------------------------
# Track generation: 1012..1269 -> 257-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-62000-to-step-62200.mp4
# Track generation: 1296..1624 -> 328-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -41.1       |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 31          |
# |    time_elapsed         | 697         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007098021 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.0629      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00252    |
# |    std                  | 0.725       |
# |    value_loss           | 3.67        |
# -----------------------------------------
# Track generation: 1143..1433 -> 290-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-64000-to-step-64200.mp4
# Track generation: 1052..1319 -> 267-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -40.1       |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 32          |
# |    time_elapsed         | 720         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005201648 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.0425      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00115    |
# |    std                  | 0.715       |
# |    value_loss           | 5.52        |
# -----------------------------------------
# Track generation: 1348..1689 -> 341-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-66000-to-step-66200.mp4
# Track generation: 946..1192 -> 246-tiles track
# Track generation: 991..1243 -> 252-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 991          |
# |    ep_rew_mean          | -39.9        |
# | time/                   |              |
# |    fps                  | 91           |
# |    iterations           | 33           |
# |    time_elapsed         | 742          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0052122446 |
# |    clip_fraction        | 0.0661       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.0143       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.23         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00386     |
# |    std                  | 0.706        |
# |    value_loss           | 10.7         |
# ------------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-68000-to-step-68200.mp4
# Track generation: 1135..1423 -> 288-tiles track
# Track generation: 1159..1453 -> 294-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 992          |
# |    ep_rew_mean          | -39.2        |
# | time/                   |              |
# |    fps                  | 90           |
# |    iterations           | 34           |
# |    time_elapsed         | 768          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0028827705 |
# |    clip_fraction        | 0.0725       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.21        |
# |    explained_variance   | -0.0207      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.42         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00202     |
# |    std                  | 0.709        |
# |    value_loss           | 40           |
# ------------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-70000-to-step-70200.mp4
# Track generation: 1088..1365 -> 277-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1007..1268 -> 261-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | -39.6       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 35          |
# |    time_elapsed         | 1043        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005700039 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.0354      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.44        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00229    |
# |    std                  | 0.701       |
# |    value_loss           | 6.59        |
# -----------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-72000-to-step-72200.mp4
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | -40.3       |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 36          |
# |    time_elapsed         | 1086        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005286541 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.595       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.759       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00208    |
# |    std                  | 0.703       |
# |    value_loss           | 1.38        |
# -----------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-74000-to-step-74200.mp4
# Track generation: 1208..1514 -> 306-tiles track
# Track generation: 1019..1278 -> 259-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | -40.5       |
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 37          |
# |    time_elapsed         | 1109        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004996768 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.512       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0011     |
# |    std                  | 0.7         |
# |    value_loss           | 1.72        |
# -----------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-76000-to-step-76200.mp4
# Track generation: 1210..1526 -> 316-tiles track
# Track generation: 1140..1428 -> 288-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 992          |
# |    ep_rew_mean          | -41.4        |
# | time/                   |              |
# |    fps                  | 68           |
# |    iterations           | 38           |
# |    time_elapsed         | 1131         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0045176065 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.643        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.48         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00174     |
# |    std                  | 0.696        |
# |    value_loss           | 3.1          |
# ------------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-78000-to-step-78200.mp4
# Track generation: 1087..1363 -> 276-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 993          |
# |    ep_rew_mean          | -40.8        |
# | time/                   |              |
# |    fps                  | 69           |
# |    iterations           | 39           |
# |    time_elapsed         | 1154         |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0035289987 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.16        |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.757        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000851    |
# |    std                  | 0.695        |
# |    value_loss           | 2.08         |
# ------------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-80000-to-step-80200.mp4
# Track generation: 1126..1419 -> 293-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 993         |
# |    ep_rew_mean          | -40.9       |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 40          |
# |    time_elapsed         | 1177        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.003911631 |
# |    clip_fraction        | 0.0225      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.000558   |
# |    std                  | 0.693       |
# |    value_loss           | 4.87        |
# -----------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-82000-to-step-82200.mp4
# Track generation: 1084..1361 -> 277-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1048..1314 -> 266-tiles track
# Track generation: 980..1229 -> 249-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 993         |
# |    ep_rew_mean          | -41.1       |
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 41          |
# |    time_elapsed         | 1200        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007473686 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.837       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00231    |
# ...
# |    loss                 | 11.2        |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.0017     |
# |    std                  | 0.649       |
# |    value_loss           | 43.6        |
# -----------------------------------------
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 899..1135 -> 236-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-226000-to-step-226200.mp4
# Track generation: 1192..1494 -> 302-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 832         |
# |    ep_rew_mean          | -52.7       |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 111         |
# |    time_elapsed         | 2838        |
# |    total_timesteps      | 227328      |
# | train/                  |             |
# |    approx_kl            | 0.012104136 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.26        |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | 0.000646    |
# |    std                  | 0.648       |
# |    value_loss           | 22.6        |
# -----------------------------------------
# Track generation: 1406..1762 -> 356-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-228000-to-step-228200.mp4
# Track generation: 1119..1403 -> 284-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 832         |
# |    ep_rew_mean          | -54.1       |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 112         |
# |    time_elapsed         | 2862        |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.014650178 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.9         |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | 0.00228     |
# |    std                  | 0.651       |
# |    value_loss           | 24.8        |
# -----------------------------------------
# Track generation: 1094..1372 -> 278-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-230000-to-step-230200.mp4
# Track generation: 1206..1512 -> 306-tiles track
# Track generation: 1284..1616 -> 332-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 825         |
# |    ep_rew_mean          | -55.3       |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 113         |
# |    time_elapsed         | 2885        |
# |    total_timesteps      | 231424      |
# | train/                  |             |
# |    approx_kl            | 0.008356707 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00294    |
# |    std                  | 0.647       |
# |    value_loss           | 3.78        |
# -----------------------------------------
# Track generation: 1283..1607 -> 324-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-232000-to-step-232200.mp4
# Track generation: 985..1240 -> 255-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 827          |
# |    ep_rew_mean          | -55.8        |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 114          |
# |    time_elapsed         | 2906         |
# |    total_timesteps      | 233472       |
# | train/                  |              |
# |    approx_kl            | 0.0048625013 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.1         |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | 0.000222     |
# |    std                  | 0.646        |
# |    value_loss           | 23.6         |
# ------------------------------------------
# Track generation: 1105..1386 -> 281-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-234000-to-step-234200.mp4
# Track generation: 1227..1538 -> 311-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 833          |
# |    ep_rew_mean          | -55.1        |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 115          |
# |    time_elapsed         | 2928         |
# |    total_timesteps      | 235520       |
# | train/                  |              |
# |    approx_kl            | 0.0053226724 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.558        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33           |
# |    n_updates            | 1140         |
# |    policy_gradient_loss | -0.00162     |
# |    std                  | 0.648        |
# |    value_loss           | 62.3         |
# ------------------------------------------
# Track generation: 1131..1418 -> 287-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-236000-to-step-236200.mp4
# Track generation: 1151..1443 -> 292-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 839          |
# |    ep_rew_mean          | -55.6        |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 116          |
# |    time_elapsed         | 2949         |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0071056415 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.94        |
# |    explained_variance   | 0.0352       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.99         |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -0.000683    |
# |    std                  | 0.648        |
# |    value_loss           | 27.8         |
# ------------------------------------------
# Track generation: 1155..1448 -> 293-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-238000-to-step-238200.mp4
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 1217..1523 -> 306-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 848          |
# |    ep_rew_mean          | -55.6        |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 117          |
# |    time_elapsed         | 2971         |
# |    total_timesteps      | 239616       |
# | train/                  |              |
# |    approx_kl            | 0.0055999607 |
# |    clip_fraction        | 0.081        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.85         |
# |    n_updates            | 1160         |
# |    policy_gradient_loss | 0.000974     |
# |    std                  | 0.652        |
# |    value_loss           | 4.66         |
# ------------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-240000-to-step-240200.mp4
# Track generation: 1257..1577 -> 320-tiles track
# Track generation: 1127..1412 -> 285-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 844         |
# |    ep_rew_mean          | -56.7       |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 118         |
# |    time_elapsed         | 2992        |
# |    total_timesteps      | 241664      |
# | train/                  |             |
# |    approx_kl            | 0.005175095 |
# |    clip_fraction        | 0.0596      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.85        |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.00414    |
# |    std                  | 0.654       |
# |    value_loss           | 29.5        |
# -----------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-242000-to-step-242200.mp4
# Track generation: 1140..1428 -> 288-tiles track
# Track generation: 1088..1364 -> 276-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 852          |
# |    ep_rew_mean          | -56.8        |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 119          |
# |    time_elapsed         | 3014         |
# |    total_timesteps      | 243712       |
# | train/                  |              |
# |    approx_kl            | 0.0066169947 |
# |    clip_fraction        | 0.0811       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.97        |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.3         |
# |    n_updates            | 1180         |
# |    policy_gradient_loss | -0.00361     |
# |    std                  | 0.655        |
# |    value_loss           | 53.2         |
# ------------------------------------------
# Track generation: 1073..1345 -> 272-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-244000-to-step-244200.mp4
# Track generation: 1198..1510 -> 312-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 853         |
# |    ep_rew_mean          | -55.6       |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 120         |
# |    time_elapsed         | 3038        |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.005196658 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.561       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.08        |
# |    n_updates            | 1190        |
# |    policy_gradient_loss | -0.000319   |
# |    std                  | 0.658       |
# |    value_loss           | 13.4        |
# -----------------------------------------
# Track generation: 982..1237 -> 255-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-246000-to-step-246200.mp4
# Track generation: 1134..1421 -> 287-tiles track
# Track generation: 1288..1614 -> 326-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 855          |
# |    ep_rew_mean          | -56.1        |
# | time/                   |              |
# |    fps                  | 80           |
# |    iterations           | 121          |
# |    time_elapsed         | 3059         |
# |    total_timesteps      | 247808       |
# | train/                  |              |
# |    approx_kl            | 0.0066448934 |
# |    clip_fraction        | 0.063        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.99        |
# |    explained_variance   | 0.721        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.81         |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.00264     |
# |    std                  | 0.658        |
# |    value_loss           | 21.4         |
# ------------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-248000-to-step-248200.mp4
# Track generation: 973..1222 -> 249-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1202..1507 -> 305-tiles track
# Track generation: 1039..1303 -> 264-tiles track
# Track generation: 1132..1423 -> 291-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 846          |
# |    ep_rew_mean          | -57.1        |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 122          |
# |    time_elapsed         | 3081         |
# |    total_timesteps      | 249856       |
# | train/                  |              |
# |    approx_kl            | 0.0061312425 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.2         |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | -0.00314     |
# |    std                  | 0.657        |
# |    value_loss           | 44.2         |
# ------------------------------------------
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-250000-to-step-250200.mp4
# Track generation: 1227..1538 -> 311-tiles track
# Track generation: 986..1239 -> 253-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 999..1259 -> 260-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 842         |
# |    ep_rew_mean          | -58.2       |
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 123         |
# |    time_elapsed         | 3103        |
# |    total_timesteps      | 251904      |
# | train/                  |             |
# |    approx_kl            | 0.003271756 |
# |    clip_fraction        | 0.0421      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.28        |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | -0.00517    |
# |    std                  | 0.656       |
# |    value_loss           | 44.9        |
# -----------------------------------------

# %% [markdown]
# ## 5. Saving RL Model

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model_250k')
model.save(PPO_path)

# %% [markdown]
# ## 6. Evaluate the RL Model

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# Track generation: 1314..1647 -> 333-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-251904-to-step-252104.mp4
# Track generation: 1083..1358 -> 275-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-254000-to-step-254200.mp4
# Track generation: 1141..1431 -> 290-tiles track
# Track generation: 1203..1517 -> 314-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-256000-to-step-256200.mp4
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1192..1494 -> 302-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-258000-to-step-258200.mp4
# Track generation: 971..1218 -> 247-tiles track
# Track generation: 978..1233 -> 255-tiles track
# Saving video to /Users/mukilankrishnakumar/Desktop/Mukilan/Professional/W&B/intro_rl/videos/3cv0xc49/rl-video-step-260000-to-step-260200.mp4
# Track generation: 1279..1603 -> 324-tiles track
# Track generation: 1147..1437 -> 290-tiles track
# (-82.4730956, 1.6772241870385838)

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>██████████████████████▇▇▆▅▅▄▄▄▄▄▄▂▂▁▁▂▂▂</td></tr><tr><td>rollout/ep_rew_mean</td><td>▃▆▆▇█▇▇▆▆▇██▇▇▇▇▆▆▅▅▆▆▆▆▅▄▄▅▄▅▅▅▆▄▃▃▂▂▂▁</td></tr><tr><td>time/fps</td><td>▇▆▇▇▇██████▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▄▅▅▅▅▅</td></tr><tr><td>train/approx_kl</td><td>▅▃▃▂▂▄▃▃▂▃▃▃▂▃▂▃▅▂▃▃▂▃▃▂▃▄▄▁▃▁▃▃▃▄▂█▄▄▃▂</td></tr><tr><td>train/clip_fraction</td><td>▆▆▂▃▃▆▃▃▂▃▄▅▂▂▂▃▇▂▃▃▁▁▃▅▅▅▆▁▇▃▅▃▂▂▂██▆▅▃</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▂▃▃▄▄▅▅▅▆▆▇▇▆▆▆▇▇▇▇▇▇▇▇▇▇████████████▇</td></tr><tr><td>train/explained_variance</td><td>▁▁▁▁▁▁▁▁▂▁▁▆▇▅▆▆▇▆▆▅▇▂▃▅▆▇▆▅▄▅▃▆▆▇██▇▁▄▇</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▁▁▁▁▁▁▁▂▁▂▄▁▁▁▁▁▁▁▁▂▂▄▁▂▃█▂▃▂▂▁▂▂▇▆▄▁▃▅▃</td></tr><tr><td>train/policy_gradient_loss</td><td>▂▁▇▆▆▁▇▅█▆▅▆▇▇█▇▅▇▆▆▇██▃▃▄▆█▆█▄▇█▄▆▇▆█▅▄</td></tr><tr><td>train/std</td><td>██▇▆▅▅▄▄▄▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/value_loss</td><td>▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▂▇▅▂▇▆▂▃▂▁▃▃▂█▄▆▁▄▇▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>251904</td></tr><tr><td>rollout/ep_len_mean</td><td>842.34998</td></tr><tr><td>rollout/ep_rew_mean</td><td>-58.19298</td></tr><tr><td>time/fps</td><td>81.0</td></tr><tr><td>train/approx_kl</td><td>0.00327</td></tr><tr><td>train/clip_fraction</td><td>0.04214</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-2.97585</td></tr><tr><td>train/explained_variance</td><td>0.7229</td></tr><tr><td>train/learning_rate</td><td>0.0003</td></tr><tr><td>train/loss</td><td>7.28485</td></tr><tr><td>train/policy_gradient_loss</td><td>-0.00517</td></tr><tr><td>train/std</td><td>0.65595</td></tr><tr><td>train/value_loss</td><td>44.85439</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">devoted-glitter-1</strong>: <a href="https://wandb.ai/mukilan/intro_to_rl/runs/3cv0xc49" target="_blank">https://wandb.ai/mukilan/intro_to_rl/runs/3cv0xc49</a><br/>Synced 5 W&B file(s), 131 media file(s), 7 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20221029_083636-3cv0xc49/logs</code>
